# %% [markdown]
# <a href="https://colab.research.google.com/github/jangdain04-lab/TA_Airpods/blob/main/TA_TeamProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yeon524/kpop-lyrics-analytics.git
# %cd kpop-lyrics-analytics
# !ls
# Out:
# Cloning into 'kpop-lyrics-analytics'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 196 (delta 3), reused 9 (delta 3), pack-reused 185 (from 1)
# Receiving objects: 100% (196/196), 41.17 MiB | 19.82 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# /content/kpop-lyrics-analytics
# analytics_kiwi.ipynb	       clustering.ipynb  lda.html    requirements.txt
# analytics_konlpy.ipynb	       datasets		 lyrics.d2v
# analytics_repeatability.ipynb  docs		 README.md

# %%
안녕하세요

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 51.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.2 MB/s eta 0:00:00
# ...

# %%
# !pip install gensim kiwipiepy-model kiwipiepy konlpy pyLDAvis wordcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 63.2 MB/s eta 0:00:00
# Using cached konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.9/495.9 kB 21.3 MB/s eta 0:00:00
# Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# ...
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.22.0-py3-none-any.whl size=79625203 sha256=0353a4f69984145434571574e71f40248a20270c36f3ea171401cb335fea2f17
# ...

# %%
# !ls datasets
# Out:
# language_ratio_per_year.csv   lyrics_word_count_kiwi.csv
# lyrics_by_year_1964_2023.csv  lyrics_word_count_konlpy.csv

# %%
import pandas as pd

df = pd.read_csv("datasets/lyrics_by_year_1964_2023.csv")
df.head()
# Out:
#          id  year       title  singer  \
# 0  30072384  1964       워싱턴광장  정 시스터즈
# 1   8150699  1964     황혼의 에레지     최양숙
# 2   5758967  1964     물새우는 해변     권혜경
# 3   4083218  1964    내일또 만납시다     금호동
# 4   3622464  1964  밀짚모자 목장아가씨     박재란
#
#                                                lyric  x_rated
# 0                                                NaN    False
# 1                                                NaN    False
# 2  고요한 밤하늘에 별이 잠들고\n밀리는 파도소리 나혼자 들으며\n외로히 홀로 날으는 ...    False
# 3  하루의 일을 끝내고 돌아가는\n거리엔 사람의 물결\n하늘엔 별이 하나 둘 반짝이면\...    False
# 4  시원한 밀짚모자\n포플라 그늘에\n양떼를 몰고가는\n목장의 아가씨\n연분홍 빛 입술...    False

# %%
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)
df['decade'] = (df['year'] // 10 * 10).astype(str) + 's'

# %%
# !wget -O nrc_ko.tsv https://raw.githubusercontent.com/linyxus/nrc-korean/master/NRC-Korean-Lexicon.tsv
