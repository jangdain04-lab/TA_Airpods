# %% [markdown]
# <a href="https://colab.research.google.com/github/jangdain04-lab/TA_Airpods/blob/main/TA_obj1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yeon524/kpop-lyrics-analytics.git
# !ls kpop-lyrics-analytics
# Out:
# Cloning into 'kpop-lyrics-analytics'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 196 (delta 3), reused 9 (delta 3), pack-reused 185 (from 1)
# Receiving objects: 100% (196/196), 41.17 MiB | 24.27 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# analytics_kiwi.ipynb	       clustering.ipynb  lda.html    requirements.txt
# analytics_konlpy.ipynb	       datasets		 lyrics.d2v
# analytics_repeatability.ipynb  docs		 README.md

# %%
# !ls kpop-lyrics-analytics/datasets
# Out:
# language_ratio_per_year.csv   lyrics_word_count_kiwi.csv
# lyrics_by_year_1964_2023.csv  lyrics_word_count_konlpy.csv

# %%
import pandas as pd

df = pd.read_csv("kpop-lyrics-analytics/datasets/lyrics_by_year_1964_2023.csv")

# 1970~2020 필터링
df = df[(df['year'] >= 1970) & (df['year'] <= 2020)]
df = df.dropna(subset=['lyric'])

df.head()
# Out:
#           id  year      title singer  \
# 171  4058660  1970      소양강처녀    김태희
# 173  3773396  1970  가는 정 오는 정    남정희
# 175  3622569  1970  이정표 없는 거리    김상진
# 176  3621632  1970  아마도 빗물이겠지    이상열
# 177  3621631  1970        난이야    이상열
#
#                                                  lyric  x_rated
# 171  해 저문 소양강에 황혼이 지면\n외로운 갈대 밭이\n슬피 우는 두견새야\n열 여덣 ...    False
# 173  아롱진 옷자락에\n서글픈 사연 안고\n내 마음은 울면서도\n겉으로는 웃으며\n사랑도...    False
# 175  이리 가면 고향이오\n저리 가면 타향인데\n이정표 없는 거리\n헤매 도는 삼거리 길...    False
# 176  맺지 못할 사랑이기에\n말없이 헤어졌고\n돌아서는 두발 길에\n이슬비는 내리네\n사...    False
# 177  난이야 난이야\n사랑을 모두 주고\n울며 떠나간 너 바보구나\n때늦은 후회지만\n너...    False

# %%
# 필터링: 1970 ~ 2020
df = df[(df['year'] >= 1970) & (df['year'] <= 2020)].copy()

# 가사 없는 행 제거
df = df.dropna(subset=['lyric'])

# %%
# !jupyter nbconvert --to script kpop-lyrics-analytics/analytics_kiwi.ipynb
# Out:
# [NbConvertApp] Converting notebook kpop-lyrics-analytics/analytics_kiwi.ipynb to script
# [NbConvertApp] Writing 30086 bytes to kpop-lyrics-analytics/analytics_kiwi.py

# %%
# !pip install -r kpop-lyrics-analytics/requirements.txt
# !pip install kiwipiepy
# Out:
# Collecting annotated-types==0.6.0 (from -r kpop-lyrics-analytics/requirements.txt (line 1))
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting anyio==4.2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 2))
#   Downloading anyio-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting appnope==0.1.3 (from -r kpop-lyrics-analytics/requirements.txt (line 3))
#   Downloading appnope-0.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting asttokens==2.4.1 (from -r kpop-lyrics-analytics/requirements.txt (line 4))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting beautifulsoup4==4.12.3 (from -r kpop-lyrics-analytics/requirements.txt (line 5))
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bs4==0.0.2 (from -r kpop-lyrics-analytics/requirements.txt (line 6))
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting certifi==2023.11.17 (from -r kpop-lyrics-analytics/requirements.txt (line 7))
#   Downloading certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2 (from -r kpop-lyrics-analytics/requirements.txt (line 8))
#   Downloading charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting click==8.1.7 (from -r kpop-lyrics-analytics/requirements.txt (line 9))
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting comm==0.2.1 (from -r kpop-lyrics-analytics/requirements.txt (line 10))
#   Downloading comm-0.2.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy==1.2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 11))
#   Downloading contourpy-1.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r kpop-lyrics-analytics/requirements.txt (line 12)) (0.12.1)
# Collecting debugpy==1.8.0 (from -r kpop-lyrics-analytics/requirements.txt (line 13))
#   Downloading debugpy-1.8.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r kpop-lyrics-analytics/requirements.txt (line 14))
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: distro==1.9.0 in /usr/local/lib/python3.12/dist-packages (from -r kpop-lyrics-analytics/requirements.txt (line 15)) (1.9.0)
# Collecting exceptiongroup==1.2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 16))
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting executing==2.0.1 (from -r kpop-lyrics-analytics/requirements.txt (line 17))
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting fonttools==4.47.2 (from -r kpop-lyrics-analytics/requirements.txt (line 18))
#   Downloading fonttools-4.47.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 6.0 MB/s eta 0:00:00
# Collecting funcy==2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 19))
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting gensim==4.3.2 (from -r kpop-lyrics-analytics/requirements.txt (line 20))
#   Downloading gensim-4.3.2.tar.gz (23.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 54.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting h11==0.14.0 (from -r kpop-lyrics-analytics/requirements.txt (line 21))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting httpcore==1.0.2 (from -r kpop-lyrics-analytics/requirements.txt (line 22))
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting httpx==0.26.0 (from -r kpop-lyrics-analytics/requirements.txt (line 23))
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting idna==3.6 (from -r kpop-lyrics-analytics/requirements.txt (line 24))
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting ipykernel==6.29.0 (from -r kpop-lyrics-analytics/requirements.txt (line 25))
#   Downloading ipykernel-6.29.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting ipython==8.20.0 (from -r kpop-lyrics-analytics/requirements.txt (line 26))
#   Downloading ipython-8.20.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting ipywidgets==8.1.1 (from -r kpop-lyrics-analytics/requirements.txt (line 27))
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting jedi==0.19.1 (from -r kpop-lyrics-analytics/requirements.txt (line 28))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting Jinja2==3.1.3 (from -r kpop-lyrics-analytics/requirements.txt (line 29))
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting joblib==1.3.2 (from -r kpop-lyrics-analytics/requirements.txt (line 30))
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting JPype1==1.5.0 (from -r kpop-lyrics-analytics/requirements.txt (line 31))
#   Downloading JPype1-1.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting jupyter_client==8.6.0 (from -r kpop-lyrics-analytics/requirements.txt (line 32))
#   Downloading jupyter_client-8.6.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter_core==5.7.1 (from -r kpop-lyrics-analytics/requirements.txt (line 33))
#   Downloading jupyter_core-5.7.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting jupyterlab-widgets==3.0.9 (from -r kpop-lyrics-analytics/requirements.txt (line 34))
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Collecting kiwipiepy==0.16.2 (from -r kpop-lyrics-analytics/requirements.txt (line 35))
#   Downloading kiwipiepy-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting kiwipiepy-model==0.16.0 (from -r kpop-lyrics-analytics/requirements.txt (line 36))
#   Downloading kiwipiepy_model-0.16.0.tar.gz (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 21.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting kiwisolver==1.4.5 (from -r kpop-lyrics-analytics/requirements.txt (line 37))
#   Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting konlpy==0.6.0 (from -r kpop-lyrics-analytics/requirements.txt (line 38))
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting lxml==5.1.0 (from -r kpop-lyrics-analytics/requirements.txt (line 39))
#   Downloading lxml-5.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting MarkupSafe==2.1.4 (from -r kpop-lyrics-analytics/requirements.txt (line 40))
#   Downloading MarkupSafe-2.1.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib==3.8.2 (from -r kpop-lyrics-analytics/requirements.txt (line 41))
#   Downloading matplotlib-3.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting matplotlib-inline==0.1.6 (from -r kpop-lyrics-analytics/requirements.txt (line 42))
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl.metadata (2.8 kB)
# Collecting mecab-python==1.0.0 (from -r kpop-lyrics-analytics/requirements.txt (line 43))
#   Downloading mecab-python-1.0.0.tar.gz (1.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mecab-python3==1.0.8 (from -r kpop-lyrics-analytics/requirements.txt (line 44))
#   Downloading mecab-python3-1.0.8.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting nest-asyncio==1.5.9 (from -r kpop-lyrics-analytics/requirements.txt (line 45))
#   Downloading nest_asyncio-1.5.9-py3-none-any.whl.metadata (2.8 kB)
# Collecting nltk==3.8.1 (from -r kpop-lyrics-analytics/requirements.txt (line 46))
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting numexpr==2.9.0 (from -r kpop-lyrics-analytics/requirements.txt (line 47))
#   Downloading numexpr-2.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Collecting numpy==1.26.3 (from -r kpop-lyrics-analytics/requirements.txt (line 48))
#   Downloading numpy-1.26.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.8 MB/s eta 0:00:00
# Collecting openai==1.10.0 (from -r kpop-lyrics-analytics/requirements.txt (line 49))
#   Downloading openai-1.10.0-py3-none-any.whl.metadata (18 kB)
# Collecting packaging==23.2 (from -r kpop-lyrics-analytics/requirements.txt (line 50))
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 51))
#   Downloading pandas-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting parso==0.8.3 (from -r kpop-lyrics-analytics/requirements.txt (line 52))
#   Downloading parso-0.8.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.12/dist-packages (from -r kpop-lyrics-analytics/requirements.txt (line 53)) (4.9.0)
# Collecting pillow==10.2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 54))
#   Downloading pillow-10.2.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting platformdirs==4.1.0 (from -r kpop-lyrics-analytics/requirements.txt (line 55))
#   Downloading platformdirs-4.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting prompt-toolkit==3.0.43 (from -r kpop-lyrics-analytics/requirements.txt (line 56))
#   Downloading prompt_toolkit-3.0.43-py3-none-any.whl.metadata (6.5 kB)
# Collecting psutil==5.9.8 (from -r kpop-lyrics-analytics/requirements.txt (line 57))
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r kpop-lyrics-analytics/requirements.txt (line 58)) (0.7.0)
# Collecting pure-eval==0.2.2 (from -r kpop-lyrics-analytics/requirements.txt (line 59))
#   Downloading pure_eval-0.2.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting pydantic==2.5.3 (from -r kpop-lyrics-analytics/requirements.txt (line 60))
#   Downloading pydantic-2.5.3-py3-none-any.whl.metadata (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.5 MB/s eta 0:00:00
# Collecting pydantic_core==2.14.6 (from -r kpop-lyrics-analytics/requirements.txt (line 61))
#   Downloading pydantic_core-2.14.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting Pygments==2.17.2 (from -r kpop-lyrics-analytics/requirements.txt (line 62))
#   Downloading pygments-2.17.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyLDAvis==3.4.1 (from -r kpop-lyrics-analytics/requirements.txt (line 63))
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyparsing==3.1.1 (from -r kpop-lyrics-analytics/requirements.txt (line 64))
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil==2.8.2 (from -r kpop-lyrics-analytics/requirements.txt (line 65))
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting pytz==2023.3.post1 (from -r kpop-lyrics-analytics/requirements.txt (line 66))
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pyzmq==25.1.2 (from -r kpop-lyrics-analytics/requirements.txt (line 67))
#   Downloading pyzmq-25.1.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting regex==2023.12.25 (from -r kpop-lyrics-analytics/requirements.txt (line 68))
#   Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.5 MB/s eta 0:00:00
# Collecting requests==2.31.0 (from -r kpop-lyrics-analytics/requirements.txt (line 69))
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting scikit-learn==1.4.0 (from -r kpop-lyrics-analytics/requirements.txt (line 70))
#   Downloading scikit_learn-1.4.0-1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.12.0 (from -r kpop-lyrics-analytics/requirements.txt (line 71))
#   Downloading scipy-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.8 MB/s eta 0:00:00
# Collecting seaborn==0.13.1 (from -r kpop-lyrics-analytics/requirements.txt (line 72))
#   Downloading seaborn-0.13.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting six==1.16.0 (from -r kpop-lyrics-analytics/requirements.txt (line 73))
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting smart-open==6.4.0 (from -r kpop-lyrics-analytics/requirements.txt (line 74))
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting sniffio==1.3.0 (from -r kpop-lyrics-analytics/requirements.txt (line 75))
#   Downloading sniffio-1.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting soupsieve==2.5 (from -r kpop-lyrics-analytics/requirements.txt (line 76))
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting stack-data==0.6.3 (from -r kpop-lyrics-analytics/requirements.txt (line 77))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting threadpoolctl==3.2.0 (from -r kpop-lyrics-analytics/requirements.txt (line 78))
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting tornado==6.4 (from -r kpop-lyrics-analytics/requirements.txt (line 79))
#   Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting tqdm==4.66.1 (from -r kpop-lyrics-analytics/requirements.txt (line 80))
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.9 MB/s eta 0:00:00
# Collecting traitlets==5.14.1 (from -r kpop-lyrics-analytics/requirements.txt (line 81))
#   Downloading traitlets-5.14.1-py3-none-any.whl.metadata (10 kB)
# Collecting typing_extensions==4.9.0 (from -r kpop-lyrics-analytics/requirements.txt (line 82))
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata==2023.4 (from -r kpop-lyrics-analytics/requirements.txt (line 83))
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.1.0 (from -r kpop-lyrics-analytics/requirements.txt (line 84))
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting wcwidth==0.2.13 (from -r kpop-lyrics-analytics/requirements.txt (line 85))
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting widgetsnbextension==4.0.9 (from -r kpop-lyrics-analytics/requirements.txt (line 86))
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting wordcloud==1.9.3 (from -r kpop-lyrics-analytics/requirements.txt (line 87))
#   Downloading wordcloud-1.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyLDAvis==3.4.1->-r kpop-lyrics-analytics/requirements.txt (line 63)) (75.2.0)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading anyio-4.2.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 6.7 MB/s eta 0:00:00
# Downloading appnope-0.1.3-py2.py3-none-any.whl (4.4 kB)
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 11.7 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 12.1 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.6 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 8.7 MB/s eta 0:00:00
# Downloading comm-0.2.1-py3-none-any.whl (7.2 kB)
# Downloading contourpy-1.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (303 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.9/303.9 kB 24.2 MB/s eta 0:00:00
# Downloading debugpy-1.8.0-py2.py3-none-any.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 116.3 MB/s eta 0:00:00
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Downloading fonttools-4.47.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 63.3 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.7 MB/s eta 0:00:00
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 6.1 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.7 MB/s eta 0:00:00
# Downloading ipykernel-6.29.0-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.1/116.1 kB 8.6 MB/s eta 0:00:00
# Downloading ipython-8.20.0-py3-none-any.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.2/809.2 kB 50.9 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 12.0 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.8 MB/s eta 0:00:00
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 10.8 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 22.4 MB/s eta 0:00:00
# Downloading JPype1-1.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.9/488.9 kB 24.4 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 7.3 MB/s eta 0:00:00
# Downloading jupyter_core-5.7.1-py3-none-any.whl (28 kB)
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 15.3 MB/s eta 0:00:00
# Downloading kiwipiepy-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 72.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.3 MB/s eta 0:00:00
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 90.8 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 115.1 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading matplotlib-3.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 108.7 MB/s eta 0:00:00
# Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Downloading nest_asyncio-1.5.9-py3-none-any.whl (5.3 kB)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 63.3 MB/s eta 0:00:00
# Downloading numexpr-2.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 kB 27.2 MB/s eta 0:00:00
# Downloading numpy-1.26.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 15.6 MB/s eta 0:00:00
# Downloading openai-1.10.0-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 12.7 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.0 MB/s eta 0:00:00
# Downloading pandas-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 47.8 MB/s eta 0:00:00
# Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 6.9 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 43.9 MB/s eta 0:00:00
# Downloading platformdirs-4.1.0-py3-none-any.whl (17 kB)
# Downloading prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 kB 17.5 MB/s eta 0:00:00
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 14.0 MB/s eta 0:00:00
# Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Downloading pydantic-2.5.3-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 19.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.14.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.3 MB/s eta 0:00:00
# Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.8 MB/s eta 0:00:00
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 44.1 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 6.6 MB/s eta 0:00:00
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 13.7 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 24.9 MB/s eta 0:00:00
# Downloading pyzmq-25.1.2-cp312-cp312-manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.0 MB/s eta 0:00:00
# Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (789 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.1/789.1 kB 32.9 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 3.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.0-1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 43.0 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 10.6 MB/s eta 0:00:00
# Downloading seaborn-0.13.1-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 17.9 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.9 MB/s eta 0:00:00
# Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 kB 26.7 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.8 MB/s eta 0:00:00
# Downloading traitlets-5.14.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 5.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 16.3 MB/s eta 0:00:00
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 6.2 MB/s eta 0:00:00
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.3 MB/s eta 0:00:00
# Downloading wordcloud-1.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.6/541.6 kB 13.4 MB/s eta 0:00:00
# Building wheels for collected packages: gensim, kiwipiepy-model, mecab-python, mecab-python3
#   Building wheel for gensim (pyproject.toml) ... done
#   Created wheel for gensim: filename=gensim-4.3.2-cp312-cp312-linux_x86_64.whl size=26332402 sha256=980181f07f3f7356fef3c29df91ec7dda975578427f9e0f6dc0ddc07074b9a18
#   Stored in directory: /root/.cache/pip/wheels/50/c0/ac/7bb08954bc59d390c848b480a3fc5eec68c14bc77bf334d624
#   Building wheel for kiwipiepy-model (setup.py) ... done
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.16.0-py3-none-any.whl size=30813256 sha256=0d24309450f2651f80d11e5bbfa0f48d4747eb9637f6ac1185ab59bd3a3fc74f
#   Stored in directory: /root/.cache/pip/wheels/bf/a9/51/ffc884e8e6aa80504fda7d87ccad5d056e85fec557cd55dcac
#   Building wheel for mecab-python (setup.py) ... done
#   Created wheel for mecab-python: filename=mecab_python-1.0.0-py3-none-any.whl size=1232 sha256=6af8e22578c92f4e0c79f19c1fe7909fb192fb7973a3c90d3c27efcc4809a496
#   Stored in directory: /root/.cache/pip/wheels/62/0e/84/39e1c8bf2f2da63964fe43fb2932027d6344f8766edf28bc8c
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for mecab-python3 (setup.py) ... error
#   ERROR: Failed building wheel for mecab-python3
#   Running setup.py clean for mecab-python3
# Successfully built gensim kiwipiepy-model mecab-python
# Failed to build mecab-python3
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (mecab-python3)
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting kiwipiepy_model<0.23,>=0.22 (from kiwipiepy)
#   Downloading kiwipiepy_model-0.22.0.tar.gz (79.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from kiwipiepy) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kiwipiepy) (4.67.1)
# Downloading kiwipiepy-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 21.7 MB/s eta 0:00:00
# Building wheels for collected packages: kiwipiepy_model
#   Building wheel for kiwipiepy_model (setup.py) ... done
#   Created wheel for kiwipiepy_model: filename=kiwipiepy_model-0.22.0-py3-none-any.whl size=79625203 sha256=6d2c2c240a410f9cd4869600c0d8071217b1494b44a3a06c9d9a47efee655c4e
#   Stored in directory: /root/.cache/pip/wheels/e5/4b/3f/aa850a40d0f9709fd4c6d37d48402ca95354264236e1205ea3
# Successfully built kiwipiepy_model
# Installing collected packages: kiwipiepy_model, kiwipiepy
# Successfully installed kiwipiepy-0.22.1 kiwipiepy_model-0.22.0

# %%
import pandas as pd
import re
# 한글/영문 비율 계산 함수
def calc_lang_ratio(text):
    hangul = re.findall(r"[가-힣]", text)
    english = re.findall(r"[A-Za-z]", text)

    h_count = len(hangul)
    e_count = len(english)
    total = len(text)

    return pd.Series({
        "hangul_ratio": h_count / total if total > 0 else 0,
        "english_ratio": e_count / total if total > 0 else 0,
        "hangul_count": h_count,
        "english_count": e_count,
        "total_chars": total
    })

# df에 적용
lang_df = df['lyric'].apply(calc_lang_ratio)
df = pd.concat([df, lang_df], axis=1)

df.head()
# Out:
#           id  year      title singer  \
# 171  4058660  1970      소양강처녀    김태희
# 173  3773396  1970  가는 정 오는 정    남정희
# 175  3622569  1970  이정표 없는 거리    김상진
# 176  3621632  1970  아마도 빗물이겠지    이상열
# 177  3621631  1970        난이야    이상열
#
#                                                  lyric  x_rated  hangul_ratio  \
# 171  해 저문 소양강에 황혼이 지면\n외로운 갈대 밭이\n슬피 우는 두견새야\n열 여덣 ...    False      0.712042
# 173  아롱진 옷자락에\n서글픈 사연 안고\n내 마음은 울면서도\n겉으로는 웃으며\n사랑도...    False      0.711656
# 175  이리 가면 고향이오\n저리 가면 타향인데\n이정표 없는 거리\n헤매 도는 삼거리 길...    False      0.686047
# 176  맺지 못할 사랑이기에\n말없이 헤어졌고\n돌아서는 두발 길에\n이슬비는 내리네\n사...    False      0.732620
# 177  난이야 난이야\n사랑을 모두 주고\n울며 떠나간 너 바보구나\n때늦은 후회지만\n너...    False      0.733668
#
#      english_ratio  hangul_count  english_count  total_chars
# 171            0.0         136.0            0.0        191.0
# 173            0.0         116.0            0.0        163.0
# 175            0.0         118.0            0.0        172.0
# 176            0.0         137.0            0.0        187.0
# 177            0.0         146.0            0.0        199.0

# %%
year_ratio = df.groupby('year')[['hangul_ratio', 'english_ratio']].mean()
year_ratio.head()
# Out:
#       hangul_ratio  english_ratio
# year
# 1970      0.720243       0.000000
# 1971      0.714106       0.012025
# 1972      0.725891       0.000000
# 1973      0.729869       0.000000
# 1974      0.724830       0.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(year_ratio.index, year_ratio['hangul_ratio'], label='Hangul Ratio', linewidth=2)
plt.plot(year_ratio.index, year_ratio['english_ratio'], label='English Ratio', linewidth=2)

plt.title("Hangul vs English Ratio in K-pop Lyrics (1970–2020)", fontsize=16)
plt.xlabel("Year")
plt.ylabel("Average Ratio")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 연도별 평균 비율
year_ratio = df.groupby('year')[['hangul_ratio', 'english_ratio']].mean().reset_index()

# 한글+영어만 100%가 되도록 정규화
denom = year_ratio['hangul_ratio'] + year_ratio['english_ratio']
korean_pct  = np.where(denom > 0, year_ratio['hangul_ratio'] / denom * 100, 0)
english_pct = np.where(denom > 0, year_ratio['english_ratio'] / denom * 100, 0)

years = year_ratio['year']

# %%
plt.figure(figsize=(16, 6))

# 한글 비율 (아래 파란 부분)
plt.bar(years, korean_pct, label='korean')

# 영어 비율 (위에 초록 부분, bottom=한글)
plt.bar(years, english_pct, bottom=korean_pct, label='english')

plt.title("1970–2020 연도별 한글/영어 가사 비율 (정규화 100%)", fontsize=16)
plt.ylabel("비율(%)")
plt.ylim(0, 100)

plt.xticks(years, rotation=60)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3379851012.py:16: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(16, 6))

# Korean ratio (blue)
plt.bar(years, korean_pct, label='Korean')

# English ratio (green) stacked above Korean
plt.bar(years, english_pct, bottom=korean_pct, label='English')

plt.title("1970–2020 Korean/English Lyrics Ratio (100% normalized)", fontsize=16)
plt.ylabel("Ratio (%)")
plt.ylim(0, 100)

plt.xticks(years, rotation=60)
plt.legend()

plt.tight_layout()
plt.show()

# %%
# !pip install kiwipiepy wordcloud
# Out:
# Requirement already satisfied: kiwipiepy in /usr/local/lib/python3.12/dist-packages (0.22.1)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: kiwipiepy_model<0.23,>=0.22 in /usr/local/lib/python3.12/dist-packages (from kiwipiepy) (0.22.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from kiwipiepy) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kiwipiepy) (4.67.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from kiwipiepy import Kiwi
from collections import Counter

kiwi = Kiwi()

# 명사/동사/형용사/부사만 남기기
ALLOWED_TAGS = {'NNG', 'NNP', 'VV', 'VA', 'MAG'}

def tokenize_lyric(text):
    tokens = []
    for tok in kiwi.tokenize(text):
        form = tok.form
        tag  = tok.tag

        if tag not in ALLOWED_TAGS:
            continue

        # 동사, 형용사는 '다' 떼고 기본형 느낌으로
        if tag in {'VV', 'VA'} and form.endswith('다'):
            form = form[:-1]

        tokens.append((form, tag))
    return tokens

# %%
# 각 곡마다 형태소 리스트 저장
df['tokens'] = df['lyric'].apply(tokenize_lyric)

# (확인)
df[['year', 'title', 'tokens']].head()
# Out:
#      year      title                                             tokens
# 171  1970      소양강처녀  [(해, NNG), (저물, VV), (소양강, NNP), (황혼, NNG), (지...
# 173  1970  가는 정 오는 정  [(아롱, NNG), (지, VV), (옷자락, NNG), (서글프, VA), (사...
# 175  1970  이정표 없는 거리  [(이리, MAG), (가, VV), (고향, NNG), (저리, MAG), (가,...
# 176  1970  아마도 빗물이겠지  [(맺, VV), (사랑, NNG), (말없이, MAG), (헤어지, VV), (돌...
# 177  1970        난이야  [(사랑, NNG), (모두, MAG), (주, VV), (울, VV), (떠나가,...

# %%
import zipfile, os

zip_path = "kpop-lyrics-analytics/notosanskr.zip"
extract_dir = "fonts"

if not os.path.exists(extract_dir):
    with zipfile.ZipFile(zip_path, 'r') as z:
        z.extractall(extract_dir)

# 폰트 파일 이름은 압축 풀린 폴더 안에서 한 번 확인해서 바꿔줘
font_path = [f for f in os.listdir(extract_dir) if f.lower().endswith('.otf') or f.lower().endswith('.ttf')][0]
font_path = os.path.join(extract_dir, font_path)
font_path
# Out:
# 'fonts/NotoSansCJKkr-Bold.otf'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def make_wordcloud(tokens, title, max_words=200):
    freq = Counter(tokens)
    wc = WordCloud(
        font_path=font_path,
        background_color='white',
        width=800,
        height=600,
        max_words=max_words
    ).generate_from_frequencies(freq)

    plt.figure(figsize=(6,6))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# %%
# Extract only the forms from tokens
all_korean_tokens = [form for row in df['tokens'] for form, tag in row]

make_wordcloud(all_korean_tokens, "Top Keywords (1970–2020)")

# %%
# Add decade column
df['decade'] = (df['year'] // 10) * 10    # 1970, 1980, ...

for decade, group in df.groupby('decade'):
    tokens_decade = [form for row in group['tokens'] for form, tag in row]

    title = f"Top Keywords of {decade}s"

    make_wordcloud(tokens_decade, title)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Token length per song
df['token_len'] = df['tokens'].apply(len)

year_len = df.groupby('year')['token_len'].mean().reset_index()

plt.figure(figsize=(10,6))
plt.scatter(year_len['year'], year_len['token_len'], alpha=0.6)

# Simple regression line
z = np.polyfit(year_len['year'], year_len['token_len'], 1)
p = np.poly1d(z)
plt.plot(year_len['year'], p(year_len['year']), linestyle='--')

plt.xlabel('Year')
plt.ylabel('Average Token Count')
plt.title('Change in Average Lyric Length by Year (based on morphemes)')
plt.show()

# %%
from collections import defaultdict

# 품사별 전체 카운트
pos_counts = defaultdict(Counter)

for row in df['tokens']:
    for form, tag in row:
        pos_counts[tag][form] += 1

# 태그를 크게 4종류로 묶자 (명사/동사/형용사/부사)
POS_MAP = {
    'NNG': 'NOUN',
    'NNP': 'NOUN',
    'VV': 'VERB',
    'VA': 'ADJ',
    'MAG': 'ADV'
}

grouped_counts = defaultdict(Counter)
for tag, cnt in pos_counts.items():
    if tag not in POS_MAP:
        continue
    big = POS_MAP[tag]
    for word, c in cnt.items():
        grouped_counts[big][word] += c

# %%
import matplotlib.pyplot as plt

def plot_top_words(counter, title, top_n=15):
    top = counter.most_common(top_n)
    words = [w for w, c in top]
    counts = [c for w, c in top]

    plt.figure(figsize=(10,4))
    plt.bar(words, counts)
    plt.xticks(rotation=45)
    plt.ylabel('count')
    plt.title(title)
    plt.tight_layout()
    plt.show()

plot_top_words(grouped_counts['NOUN'], "명사 상위 15개")
plot_top_words(grouped_counts['VERB'], "동사 상위 15개")
plot_top_words(grouped_counts['ADJ'],  "형용사 상위 15개")
plot_top_words(grouped_counts['ADV'],  "부사 상위 15개")
# Out:
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46412 (\N{HANGUL SYLLABLE DDAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 45576 (\N{HANGUL SYLLABLE NUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47576 (\N{HANGUL SYLLABLE MAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 48164 (\N{HANGUL SYLLABLE BAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49844 (\N{HANGUL SYLLABLE SEUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46412 (\N{HANGUL SYLLABLE DDAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45576 (\N{HANGUL SYLLABLE NUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47576 (\N{HANGUL SYLLABLE MAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48164 (\N{HANGUL SYLLABLE BAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49844 (\N{HANGUL SYLLABLE SEUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46104 (\N{HANGUL SYLLABLE DOE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51082 (\N{HANGUL SYLLABLE IJ}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51080 (\N{HANGUL SYLLABLE ISS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46496 (\N{HANGUL SYLLABLE DDEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46104 (\N{HANGUL SYLLABLE DOE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50508 (\N{HANGUL SYLLABLE AL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51082 (\N{HANGUL SYLLABLE IJ}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51080 (\N{HANGUL SYLLABLE ISS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46496 (\N{HANGUL SYLLABLE DDEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50630 (\N{HANGUL SYLLABLE EOBS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44057 (\N{HANGUL SYLLABLE GAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51339 (\N{HANGUL SYLLABLE JOH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49836 (\N{HANGUL SYLLABLE SEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47566 (\N{HANGUL SYLLABLE MANH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49899 (\N{HANGUL SYLLABLE SILH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47680 (\N{HANGUL SYLLABLE MEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 55192 (\N{HANGUL SYLLABLE HIM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44316 (\N{HANGUL SYLLABLE GWAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 52270 (\N{HANGUL SYLLABLE CANH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49240 (\N{HANGUL SYLLABLE BBEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44618 (\N{HANGUL SYLLABLE GIP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50630 (\N{HANGUL SYLLABLE EOBS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44057 (\N{HANGUL SYLLABLE GAT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51339 (\N{HANGUL SYLLABLE JOH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49836 (\N{HANGUL SYLLABLE SEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47566 (\N{HANGUL SYLLABLE MANH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49899 (\N{HANGUL SYLLABLE SILH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47680 (\N{HANGUL SYLLABLE MEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 55192 (\N{HANGUL SYLLABLE HIM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44316 (\N{HANGUL SYLLABLE GWAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52270 (\N{HANGUL SYLLABLE CANH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49240 (\N{HANGUL SYLLABLE BBEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44618 (\N{HANGUL SYLLABLE GIP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 45908 (\N{HANGUL SYLLABLE DEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 45320 (\N{HANGUL SYLLABLE NEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46608 (\N{HANGUL SYLLABLE DDO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50780 (\N{HANGUL SYLLABLE WAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51649 (\N{HANGUL SYLLABLE JIG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 54632 (\N{HANGUL SYLLABLE HAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 44760 (\N{HANGUL SYLLABLE GGE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 51096 (\N{HANGUL SYLLABLE JAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-2242449279.py:13: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45908 (\N{HANGUL SYLLABLE DEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45320 (\N{HANGUL SYLLABLE NEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46608 (\N{HANGUL SYLLABLE DDO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50780 (\N{HANGUL SYLLABLE WAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51649 (\N{HANGUL SYLLABLE JIG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54632 (\N{HANGUL SYLLABLE HAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44760 (\N{HANGUL SYLLABLE GGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51096 (\N{HANGUL SYLLABLE JAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
stopwords = set([
    "있", "없", "때", "말", "좀", "더", "왜", "또", "난", "난다", "그냥",
    "아직", "이제", "정말", "마저", "다시", "너무", "보다", "처럼", "에게",
    "에서", "으로", "까지", "만큼", "뿐", "듯", "건", "거", "것",
    "내", "네", "나", "너", "우리", "모든",
    "은", "는", "이", "가", "을", "를", "도", "와", "과", "에", "의",
])

# %%
def clean_tokens(token_list):
    return [
        form for form, tag in token_list
        if form not in stopwords
        and len(form) > 1  # 한 글자 단어 제거
        and tag not in ["JKS", "JKC", "JKB", "JKG", "JKO", "JX", "JC", "EP", "EF", "EC", "ETN", "ETM"]
        # 조사, 어미 제거
    ]

# %%
df['clean_tokens'] = df['tokens'].apply(clean_tokens)

# %%
# 1) decade 컬럼 만들기 (이미 있으면 다시 안 만들어도 됨)
df['decade'] = (df['year'] // 10) * 10   # 1970, 1980, ...

# 2) 전처리된 clean_tokens로 10년대별 워드클라우드 만들기
for decade, group in df.groupby('decade'):
    # 이 10년대에 속한 곡들의 clean_tokens 다 펼치기
    tokens_decade = [form for row in group['clean_tokens'] for form in row]

    # 워드클라우드 그리기
    make_wordcloud(tokens_decade, f"Top Keywords of {decade}s")

# %%
# (형태소만 뽑기: form만)  → 전처리 적용 버전
all_korean_tokens = [form for row in df['clean_tokens'] for form in row]
make_wordcloud(all_korean_tokens, "Top Keywords of 1970–2020 (cleaned)")

# %%
# 가사 길이(글자 수)
df['lyric_len'] = df['lyric'].apply(lambda x: len(str(x)))

# 가장 긴 가사 TOP 20
longest_lyrics = df.sort_values('lyric_len', ascending=False).head(20)
print(longest_lyrics[['year', 'singer', 'title', 'lyric_len']])

# 가장 짧은 가사 TOP 20
shortest_lyrics = df.sort_values('lyric_len', ascending=True).head(20)
print(shortest_lyrics[['year', 'singer', 'title', 'lyric_len']])
# Out:
#       year                                    singer  \
# 3959  2016                                 BewhY 비와이
# 3152  2008                                BIGBANG 빅뱅
# 4328  2020                            백예린 Yerin Baek
# 4193  2019                                      기리보이
# 3178  2009                                SHINee 샤이니
# 4269  2020                                     방탄소년단
# 2771  2005                                       이효리
# 4251  2019                                       pH1
# 4072  2018                                       pH1
# 4329  2020  염따 딥플로우 팔로알토 Paloalto The Quiett 사이먼 도미닉
# 3777  2015                           Red Velvet 레드벨벳
# 4094  2018                                     방탄소년단
# 3976  2017                                        행주
# 2261  1999                                   드렁큰 타이거
# 2538  2002                                       윤미래
# 3943  2016                                    싸이 PSY
# 3977  2017                                        넉살
# 3376  2011                                       윤미래
# 3596  2013                                      2NE1
# 3359  2010                                        현아
#
#                                                   title  lyric_len
# 3959                                   The Time Goes On       2679
# 3152                                        How Gee 하우지       2552
# 4328                                        Square 2017       2549
# 4193        아퍼 Feat Kid Milli Lil tachi 김승민 NOEL C JAMM       2291
# 3178                                     Ring Ding Dong       2205
# 4269                                           Dynamite       2156
# 2771  Anyclub FeatTeddy  CF  Anycall Anyclub 이효리 에릭 ...       2118
# 4251                     Good Day Feat 팔로알토 Prod 코드 쿤스트       2111
# 4072                     Good Day Feat 팔로알토 Prod 코드 쿤스트       2111
# 4329                   아마두 feat우원재 김효은 넉살 Huckleberry P       2094
# 3777                                          Dumb Dumb       2039
# 4094                                           Anpanman       1995
# 3976                                요즘것들 Feat ZICO DEAN       1976
# 2261                                             난 널 원해       1960
# 2538                             Memories Smiling Tears       1954
# 3943                              DADDY Feat CL of 2NE1       1941
# 3977                                   N분의1 Feat 다이나믹듀오       1929
# 3376              Get It In Feat Tiger JK 정인 Korean Ver       1907
# 3596                                    Falling In Love       1906
# 3359                         Change Feat 용준형 From Beast       1895
#       year      singer       title  lyric_len
# 2784  2005      SG 워너비  내 마음의 보석상자         95
# 1141  1988         길은정         사랑굿         96
# 484   1978         윤수일   사랑만은 않겠어요         98
# 358   1975         이수만   모든 것 끝난 뒤        110
# 218   1971         나훈아        가지마오        113
# 415   1976         산이슬         두마음        113
# 547   1979       홍삼트리오          기도        117
# 1235  1989         이승철     사랑하고 싶어        121
# 1287  1990      신촌 블루스      진고개 신사        124
# 266   1972         이필원          고독        127
# 462   1977         조용필           정        128
# 197   1971  Toi Et Moi    그리운 사람끼리        131
# 1129  1988         이건주       우리 엄마        131
# 269   1972         박인희         모닥불        132
# 699   1984         신형원          불씨        134
# 326   1974         차중락      그대는 가고        135
# 575   1980     Nami 나미     미운정 고운정        136
# 220   1971        키보이스   정든 배는 떠난다        138
# 1301  1990         주병선         칠갑산        142
# 223   1971         송창식  창밖에는 비 오고요        143

# %%
# --- Install Hangul font (Colab) ---
# !sudo apt-get install -qq fonts-noto-cjk

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Noto Sans CJK KR'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-noto-cjk.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../fonts-noto-cjk_1%3a20220127+repack1-1_all.deb ...
# Unpacking fonts-noto-cjk (1:20220127+repack1-1) ...
# Setting up fonts-noto-cjk (1:20220127+repack1-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib as mpl

# 폰트 경로 직접 등록
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
fontprop = fm.FontProperties(fname=font_path)

# matplotlib 전역 설정
mpl.rcParams['font.family'] = fontprop.get_name()
mpl.rcParams['axes.unicode_minus'] = False

print("사용 중인 폰트:", fontprop.get_name())
# Out:
# 사용 중인 폰트: NanumGothic

# %%
plt.figure()
plt.plot([1,2,3],[1,4,9])
plt.title("한글 테스트: 방탄소년단 / 아이유 / 레드벨벳", fontproperties=fontprop)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'NanumBarunGothic'   # 한글 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
from matplotlib import font_manager as fm
import matplotlib.pyplot as plt

font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
font_prop = fm.FontProperties(fname=font_path)

top_long = (
    longest_lyrics
    .head(20)
    .sort_values('lyric_len', ascending=True)
)

plt.figure(figsize=(10, 8))
plt.barh(
    top_long['title'] + " - " + top_long['singer'],
    top_long['lyric_len']
)

plt.title("Top 20 Songs with Longest Lyrics (by characters)", fontproperties=font_prop)
plt.xlabel("Lyrics length (number of characters)", fontproperties=font_prop)
plt.ylabel("Song (title - artist)", fontproperties=font_prop)

plt.yticks(fontproperties=font_prop)  # 🎯 y축 라벨(노래제목)도 폰트 적용됨

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.

# %%
from matplotlib import font_manager as fm
import matplotlib.pyplot as plt

# 폰트 파일 경로 (Colab에서도 존재)
font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
font_prop = fm.FontProperties(fname=font_path)

# 짧은 가사 Top 20
top_short = (
    shortest_lyrics
    .head(20)
    .sort_values('lyric_len', ascending=True)
)

plt.figure(figsize=(10, 8))
plt.barh(
    top_short['title'] + " - " + top_short['singer'],
    top_short['lyric_len']
)

plt.title("Top 20 Songs with Shortest Lyrics (by characters)", fontproperties=font_prop)
plt.xlabel("Lyrics length (number of characters)", fontproperties=font_prop)
plt.ylabel("Song (title - artist)", fontproperties=font_prop)

plt.yticks(fontproperties=font_prop)  # 🎯 y축에 폰트 적용 (제목/가수 한글!)

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.

# %%
df['token_len'] = df['tokens'].apply(len)

most_tokens = df.sort_values('token_len', ascending=False).head(20)
print(most_tokens[['year', 'singer', 'title', 'token_len']])
# Out:
#       year                                    singer  \
# 4329  2020  염따 딥플로우 팔로알토 Paloalto The Quiett 사이먼 도미닉
# 3959  2016                                 BewhY 비와이
# 3977  2017                                        넉살
# 3976  2017                                        행주
# 4193  2019                                      기리보이
# 2357  2000                                        주석
# 3600  2013                                     아웃사이더
# 4106  2018                                  김하온 HAON
# 2193  1999                                      젝스키스
# 4229  2019              Jvcki Wai 양홍원 Osshun Gum 한요한
# 2311  2000                                       업타운
# 2523  2002                                 YG Family
# 2207  1999                                       브로스
# 2512  2002                                   CB Mass
# 2629  2003                                   드렁큰 타이거
# 3396  2011                                        리쌍
# 2211  1999                                    허니 패밀리
# 2724  2004                                       MC몽
# 3214  2009                                     아웃사이더
# 3893  2016                                   사이먼 도미닉
#
#                                             title  token_len
# 4329             아마두 feat우원재 김효은 넉살 Huckleberry P        430
# 3959                             The Time Goes On        377
# 3977                             N분의1 Feat 다이나믹듀오        376
# 3976                          요즘것들 Feat ZICO DEAN        360
# 4193  아퍼 Feat Kid Milli Lil tachi 김승민 NOEL C JAMM        348
# 2357                                         飛上비상        325
# 3600                             슬피 우는 새 Feat 이수영        321
# 4106                          바코드 Prod GroovyRoom        317
# 2193                                    연정폼생폼사기사도        309
# 4229                               띵 Prod By 기리보이        298
# 2311                                UPT Paradoxxx        295
# 2523                                       멋쟁이 신사        294
# 2207                                       Winwin        292
# 2512                                         구해주오        286
# 2629                                      남자기 때문에        285
# 3396                                  회상 Feat 백지영        282
# 2211                                 남자이야기 My Way        279
# 2724                       180˚ Feat 인태  Supasize        277
# 3214                                          외톨이        274
# 3893                             맘 편히 Comfortable        272

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm

# --- 한글 폰트 지정 (Colab에서도 100% 존재하는 경로) ---
font_path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"
font_prop = fm.FontProperties(fname=font_path)

# --- Top 20 songs by number of tokens ---
top_tokens = (
    most_tokens
    .head(20)
    .sort_values('token_len', ascending=True)   # barh는 아래→위로 증가
)

plt.figure(figsize=(10, 8))

plt.barh(
    top_tokens['title'] + " - " + top_tokens['singer'],
    top_tokens['token_len']
)

plt.title("Top 20 Songs with Most Tokens (Morpheme Count)", fontproperties=font_prop)
plt.xlabel("Number of Tokens", fontproperties=font_prop)
plt.ylabel("Song (title - artist)", fontproperties=font_prop)

# y축 라벨(곡명-가수명)에 한글 폰트 적용
plt.yticks(fontproperties=font_prop)

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.

# %%
# 가수별 평균 가사 길이 (곡 5곡 이상)
artist_stats = (
    df.groupby('singer')
      .agg(avg_len=('lyric_len', 'mean'), songs=('title', 'count'))
      .query('songs >= 5')
      .sort_values('avg_len', ascending=False)
      .head(20)
)

artist_stats
# Out:
#                      avg_len  songs
# singer
# 드렁큰 타이거          1436.833333      6
# 4minute          1388.111111      9
# 업타운              1369.600000      5
# MC몽              1308.555556     18
# 다이나믹 듀오          1247.200000      5
# Red Velvet 레드벨벳  1245.545455     11
# CNBLUE 씨엔블루      1197.857143      7
# TWICE 트와이스       1196.875000     16
# 블락비 Block B      1193.666667      6
# 시크릿              1192.571429      7
# 씨스타              1186.571429     14
# 지누션              1184.833333      6
# EXO              1175.555556      9
# 에픽하이 EPIK HIGH   1166.500000     12
# BIGBANG 빅뱅       1166.228571     35
# 신화               1164.454545     11
# 방탄소년단            1163.592593     27
# 마이티 마우스          1161.714286      7
# 2NE1             1132.368421     19
# SHINee 샤이니       1127.875000      8

# %%
decade_len = df.groupby('decade')['lyric_len'].mean().reset_index()

plt.figure(figsize=(10,6))
plt.plot(decade_len['decade'], decade_len['lyric_len'], marker='o')
plt.title("Average Lyrics Length by Decade (1970–2020)")
plt.xlabel("Decade")
plt.ylabel("Avg lyric length (characters)")
plt.grid(True)
plt.show()

# %%
emotion_dict = {
    "love": ["사랑", "좋아", "그리움", "보고싶어", "연인"],
    "sad": ["눈물", "아프", "슬프", "이별", "후회"],
    "anger": ["미워", "화", "짜증", "분노"],
}

# 감정 단어 포함 여부 count
def emotion_score(tokens):
    words = [form for form, tag in tokens]
    return {
        emo: sum(word in words for word in emotion_dict[emo])
        for emo in emotion_dict
    }

df_emotion = df['tokens'].apply(emotion_score).apply(pd.Series)
df_emotion['year'] = df['year']

emotion_by_year = df_emotion.groupby('year').sum()
emotion_by_year.plot(figsize=(12,6))
plt.title("Emotion Keyword Trend over Time")
plt.show()

# %%
df['unique_tokens'] = df['tokens'].apply(lambda x: len(set([t[0] for t in x])))

lex_div = df.groupby('year')['unique_tokens'].mean().reset_index()

plt.figure(figsize=(12,6))
plt.plot(lex_div['year'], lex_div['unique_tokens'])
plt.title("Lexical Diversity of Lyrics by Year")
plt.xlabel("Year")
plt.ylabel("Unique token count")
plt.show()
